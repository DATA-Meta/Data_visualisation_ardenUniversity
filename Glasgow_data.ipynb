# %%
import pandas as pd
import numpy as numpy
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv(r'D:\MS_Data_Science_Arden_university\Data Visualisation\07\Glasgow_Activity 2 (2).csv')
df.head()
# Out:
#           X          Y  OBJECTID POSTCODE  TotalProperties  HAProperties  \
# 0 -4.324043  55.873935         1  G11 7AX                2             0
# 1 -4.300578  55.873744         2  G11 5HA               22             0
# 2 -4.314522  55.867901         3  G11 6BQ               44             0
# 3 -4.324773  55.878672         4  G11 7AZ               22             0
# 4 -4.300006  55.873530         5  G11 5HB                9             0
#
#    FractionHAProperties  OtherProperties  FractionOtherProperties  ADDRESS  \
# 0                     0                2                        1  G11 7AX
# 1                     0               22                        1  G11 5HA
# 2                     0               44                        1  G11 6BQ
# 3                     0               22                        1  G11 7AZ
# 4                     0                9                        1  G11 5HB
#
#     LATITUDE  LONGITUDE  EASTING  NORTHING        CONSTITUENCY  \
# ...

# %%
#Create a plotly X-axis, Latitude Y-axis, Longitude Colour by Constituen
fig=px.scatter(df,x='LATITUDE',y='LONGITUDE', color='CONSTITUENCY',title='Constituencies')
fig.show()
